# %% [markdown]
# # Using a covid API - Parsing and visualizing data:

# %% [markdown]
# Importing necessary modules:

# %%
import requests

# %% [markdown]
# Getting request from [COVID19 API](https://covid19api.com/):

# %%
req = requests.get(url = 'https://api.covid19api.com/summary')

# %% [markdown]
# Reading the json output:

# %%
rawdata = req.json()

# %%
rawdata
# Out:
# {'Global': {'NewConfirmed': 86850,
#   'TotalConfirmed': 2894581,
#   'NewDeaths': 5839,
#   'TotalDeaths': 202795,
#   'NewRecovered': 27616,
#   'TotalRecovered': 815948},
#  'Countries': [{'Country': 'ALA Aland Islands',
#    'CountryCode': 'AX',
#    'Slug': 'ala-aland-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 112,
#    'TotalConfirmed': 1463,
#    'NewDeaths': 4,
#    'TotalDeaths': 47,
#    'NewRecovered': 0,
#    'TotalRecovered': 188,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 34,
#    'TotalConfirmed': 712,
#    'NewDeaths': 0,
#    'TotalDeaths': 27,
#    'NewRecovered': 9,
#    'TotalRecovered': 403,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 129,
#    'TotalConfirmed': 3256,
#    'NewDeaths': 4,
#    'TotalDeaths': 419,
#    'NewRecovered': 71,
#    'TotalRecovered': 1479,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'American Samoa',
#    'CountryCode': 'AS',
#    'Slug': 'american-samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 738,
#    'NewDeaths': 0,
#    'TotalDeaths': 40,
#    'NewRecovered': 0,
#    'TotalRecovered': 344,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Anguilla',
#    'CountryCode': 'AI',
#    'Slug': 'anguilla',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Antarctica',
#    'CountryCode': 'AQ',
#    'Slug': 'antarctica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 11,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 173,
#    'TotalConfirmed': 3780,
#    'NewDeaths': 9,
#    'TotalDeaths': 185,
#    'NewRecovered': 54,
#    'TotalRecovered': 1030,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 81,
#    'TotalConfirmed': 1677,
#    'NewDeaths': 1,
#    'TotalDeaths': 28,
#    'NewRecovered': 75,
#    'TotalRecovered': 803,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Aruba',
#    'CountryCode': 'AW',
#    'Slug': 'aruba',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 6694,
#    'NewDeaths': 1,
#    'TotalDeaths': 80,
#    'NewRecovered': 99,
#    'TotalRecovered': 4223,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 77,
#    'TotalConfirmed': 15148,
#    'NewDeaths': 6,
#    'TotalDeaths': 536,
#    'NewRecovered': 231,
#    'TotalRecovered': 12103,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 1617,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 67,
#    'TotalRecovered': 1080,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 78,
#    'NewDeaths': 0,
#    'TotalDeaths': 11,
#    'NewRecovered': 0,
#    'TotalRecovered': 15,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 70,
#    'TotalConfirmed': 2588,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 47,
#    'TotalRecovered': 1160,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 309,
#    'TotalConfirmed': 4998,
#    'NewDeaths': 9,
#    'TotalDeaths': 140,
#    'NewRecovered': 1,
#    'TotalRecovered': 113,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 79,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 31,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 817,
#    'TotalConfirmed': 9590,
#    'NewDeaths': 4,
#    'TotalDeaths': 67,
#    'NewRecovered': 453,
#    'TotalRecovered': 1573,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 1032,
#    'TotalConfirmed': 45325,
#    'NewDeaths': 238,
#    'TotalDeaths': 6917,
#    'NewRecovered': 295,
#    'TotalRecovered': 10417,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 54,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 27,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Bermuda',
#    'CountryCode': 'BM',
#    'Slug': 'bermuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 59,
#    'TotalConfirmed': 866,
#    'NewDeaths': 2,
#    'TotalDeaths': 46,
#    'NewRecovered': 0,
#    'TotalRecovered': 54,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 65,
#    'TotalConfirmed': 1486,
#    'NewDeaths': 2,
#    'TotalDeaths': 57,
#    'NewRecovered': 54,
#    'TotalRecovered': 592,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Bouvet Island',
#    'CountryCode': 'BV',
#    'Slug': 'bouvet-island',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 5281,
#    'TotalConfirmed': 59324,
#    'NewDeaths': 353,
#    'TotalDeaths': 4057,
#    'NewRecovered': 1505,
#    'TotalRecovered': 29160,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'British Indian Ocean Territory',
#    'CountryCode': 'IO',
#    'Slug': 'british-indian-ocean-territory',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'British Virgin Islands',
#    'CountryCode': 'VG',
#    'Slug': 'british-virgin-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 138,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 1,
#    'TotalRecovered': 121,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 1247,
#    'NewDeaths': 1,
#    'TotalDeaths': 55,
#    'NewRecovered': 0,
#    'TotalRecovered': 197,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 629,
#    'NewDeaths': 0,
#    'TotalDeaths': 41,
#    'NewRecovered': 17,
#    'TotalRecovered': 442,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 122,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 117,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 88,
#    'TotalConfirmed': 1518,
#    'NewDeaths': 10,
#    'TotalDeaths': 53,
#    'NewRecovered': 29,
#    'TotalRecovered': 697,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 1437,
#    'TotalConfirmed': 45491,
#    'NewDeaths': 163,
#    'TotalDeaths': 2546,
#    'NewRecovered': 864,
#    'TotalRecovered': 16013,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 90,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Cayman Islands',
#    'CountryCode': 'KY',
#    'Slug': 'cayman-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 10,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 46,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 7,
#    'TotalRecovered': 15,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 552,
#    'TotalConfirmed': 12858,
#    'NewDeaths': 7,
#    'TotalDeaths': 181,
#    'NewRecovered': 419,
#    'TotalRecovered': 6746,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 83909,
#    'NewDeaths': 0,
#    'TotalDeaths': 4636,
#    'NewRecovered': 66,
#    'TotalRecovered': 78175,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Christmas Island',
#    'CountryCode': 'CX',
#    'Slug': 'christmas-island',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Cocos (Keeling) Islands',
#    'CountryCode': 'CC',
#    'Slug': 'cocos-keeling-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 261,
#    'TotalConfirmed': 5142,
#    'NewDeaths': 8,
#    'TotalDeaths': 233,
#    'NewRecovered': 64,
#    'TotalRecovered': 1067,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 200,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 19,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 22,
#    'TotalConfirmed': 416,
#    'NewDeaths': 3,
#    'TotalDeaths': 28,
#    'NewRecovered': 1,
#    'TotalRecovered': 49,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Cook Islands',
#    'CountryCode': 'CK',
#    'Slug': 'cook-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 693,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 26,
#    'TotalRecovered': 242,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 2016,
#    'NewDeaths': 3,
#    'TotalDeaths': 54,
#    'NewRecovered': 52,
#    'TotalRecovered': 1034,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 52,
#    'TotalConfirmed': 1337,
#    'NewDeaths': 2,
#    'TotalDeaths': 51,
#    'NewRecovered': 21,
#    'TotalRecovered': 437,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 810,
#    'NewDeaths': 0,
#    'TotalDeaths': 14,
#    'NewRecovered': 50,
#    'TotalRecovered': 148,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 79,
#    'TotalConfirmed': 7352,
#    'NewDeaths': 4,
#    'TotalDeaths': 218,
#    'NewRecovered': 82,
#    'TotalRecovered': 2453,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1077,
#    'NewDeaths': 0,
#    'TotalDeaths': 14,
#    'NewRecovered': 0,
#    'TotalRecovered': 419,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 235,
#    'TotalConfirmed': 8643,
#    'NewDeaths': 15,
#    'TotalDeaths': 418,
#    'NewRecovered': 143,
#    'TotalRecovered': 5858,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 1008,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 43,
#    'TotalRecovered': 373,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 3,
#    'TotalRecovered': 13,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 177,
#    'TotalConfirmed': 5926,
#    'NewDeaths': 6,
#    'TotalDeaths': 273,
#    'NewRecovered': 59,
#    'TotalRecovered': 822,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22719,
#    'NewDeaths': 0,
#    'TotalDeaths': 576,
#    'NewRecovered': 0,
#    'TotalRecovered': 1366,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 227,
#    'TotalConfirmed': 4319,
#    'NewDeaths': 13,
#    'TotalDeaths': 307,
#    'NewRecovered': 39,
#    'TotalRecovered': 1114,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 274,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 0,
#    'TotalRecovered': 75,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 44,
#    'TotalConfirmed': 258,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 2,
#    'TotalRecovered': 13,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 30,
#    'TotalConfirmed': 1635,
#    'NewDeaths': 0,
#    'TotalDeaths': 46,
#    'NewRecovered': 22,
#    'TotalRecovered': 228,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 122,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 4,
#    'TotalRecovered': 29,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Falkland Islands (Malvinas)',
#    'CountryCode': 'FK',
#    'Slug': 'falkland-islands-malvinas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Faroe Islands',
#    'CountryCode': 'FO',
#    'Slug': 'faroe-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 10,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 80,
#    'TotalConfirmed': 4475,
#    'NewDeaths': 9,
#    'TotalDeaths': 186,
#    'NewRecovered': 0,
#    'TotalRecovered': 2500,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 1692,
#    'TotalConfirmed': 161644,
#    'NewDeaths': 369,
#    'TotalDeaths': 22648,
#    'NewRecovered': 1101,
#    'TotalRecovered': 45372,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'French Guiana',
#    'CountryCode': 'GF',
#    'Slug': 'french-guiana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'French Polynesia',
#    'CountryCode': 'PF',
#    'Slug': 'french-polynesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'French Southern Territories',
#    'CountryCode': 'TF',
#    'Slug': 'french-southern-territories',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 176,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 4,
#    'TotalRecovered': 30,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 6,
#    'TotalRecovered': 8,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 456,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 7,
#    'TotalRecovered': 139,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 1514,
#    'TotalConfirmed': 156513,
#    'NewDeaths': 117,
#    'TotalDeaths': 5877,
#    'NewRecovered': 0,
#    'TotalRecovered': 109800,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1279,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 134,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Gibraltar',
#    'CountryCode': 'GI',
#    'Slug': 'gibraltar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 16,
#    'TotalConfirmed': 2506,
#    'NewDeaths': 0,
#    'TotalDeaths': 130,
#    'NewRecovered': 0,
#    'TotalRecovered': 577,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Greenland',
#    'CountryCode': 'GL',
#    'Slug': 'greenland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 18,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Guadeloupe',
#    'CountryCode': 'GP',
#    'Slug': 'guadeloupe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Guam',
#    'CountryCode': 'GU',
#    'Slug': 'guam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 43,
#    'TotalConfirmed': 473,
#    'NewDeaths': 2,
#    'TotalDeaths': 13,
#    'NewRecovered': 15,
#    'TotalRecovered': 45,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Guernsey',
#    'CountryCode': 'GG',
#    'Slug': 'guernsey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 42,
#    'TotalConfirmed': 996,
#    'NewDeaths': 1,
#    'TotalDeaths': 7,
#    'NewRecovered': 17,
#    'TotalRecovered': 208,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 52,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 73,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 12,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 72,
#    'NewDeaths': 1,
#    'TotalDeaths': 6,
#    'NewRecovered': 4,
#    'TotalRecovered': 6,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Heard and Mcdonald Islands',
#    'CountryCode': 'HM',
#    'Slug': 'heard-and-mcdonald-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 36,
#    'TotalConfirmed': 627,
#    'NewDeaths': 4,
#    'TotalDeaths': 59,
#    'NewRecovered': 7,
#    'TotalRecovered': 65,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Hong Kong, SAR China',
#    'CountryCode': 'HK',
#    'Slug': 'hong-kong-sar-china',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2443,
#    'NewDeaths': 0,
#    'TotalDeaths': 262,
#    'NewRecovered': 0,
#    'TotalRecovered': 458,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 1790,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 28,
#    'TotalRecovered': 1570,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 1753,
#    'TotalConfirmed': 26283,
#    'NewDeaths': 45,
#    'TotalDeaths': 825,
#    'NewRecovered': 441,
#    'TotalRecovered': 5939,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 396,
#    'TotalConfirmed': 8607,
#    'NewDeaths': 31,
#    'TotalDeaths': 720,
#    'NewRecovered': 40,
#    'TotalRecovered': 1042,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 1134,
#    'TotalConfirmed': 89328,
#    'NewDeaths': 76,
#    'TotalDeaths': 5650,
#    'NewRecovered': 1594,
#    'TotalRecovered': 68193,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 55,
#    'TotalConfirmed': 1763,
#    'NewDeaths': 0,
#    'TotalDeaths': 86,
#    'NewRecovered': 20,
#    'TotalRecovered': 1224,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 377,
#    'TotalConfirmed': 18561,
#    'NewDeaths': 49,
#    'TotalDeaths': 1063,
#    'NewRecovered': 0,
#    'TotalRecovered': 9233,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Isle of Man',
#    'CountryCode': 'IM',
#    'Slug': 'isle-of-man',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 240,
#    'TotalConfirmed': 15298,
#    'NewDeaths': 5,
#    'TotalDeaths': 199,
#    'NewRecovered': 432,
#    'TotalRecovered': 6435,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 2357,
#    'TotalConfirmed': 195351,
#    'NewDeaths': 415,
#    'TotalDeaths': 26384,
#    'NewRecovered': 2622,
#    'TotalRecovered': 63120,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 305,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 28,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 402,
#    'TotalConfirmed': 13231,
#    'NewDeaths': 15,
#    'TotalDeaths': 360,
#    'NewRecovered': 126,
#    'TotalRecovered': 1656,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Jersey',
#    'CountryCode': 'JE',
#    'Slug': 'jersey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 444,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 6,
#    'TotalRecovered': 332,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 119,
#    'TotalConfirmed': 2601,
#    'NewDeaths': 0,
#    'TotalDeaths': 25,
#    'NewRecovered': 42,
#    'TotalRecovered': 646,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 343,
#    'NewDeaths': 0,
#    'TotalDeaths': 14,
#    'NewRecovered': 4,
#    'TotalRecovered': 98,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Korea (North)',
#    'CountryCode': 'KP',
#    'Slug': 'korea-north',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 10728,
#    'NewDeaths': 2,
#    'TotalDeaths': 242,
#    'NewRecovered': 82,
#    'TotalRecovered': 8717,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 278,
#    'TotalConfirmed': 2892,
#    'NewDeaths': 4,
#    'TotalDeaths': 19,
#    'NewRecovered': 43,
#    'TotalRecovered': 656,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 665,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 0,
#    'TotalRecovered': 345,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 3,
#    'TotalRecovered': 7,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 20,
#    'TotalConfirmed': 804,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 267,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 704,
#    'NewDeaths': 2,
#    'TotalDeaths': 24,
#    'NewRecovered': 3,
#    'TotalRecovered': 143,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 120,
#    'NewDeaths': 3,
#    'TotalDeaths': 11,
#    'NewRecovered': 0,
#    'TotalRecovered': 25,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 61,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 18,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 81,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 55,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 16,
#    'TotalConfirmed': 1426,
#    'NewDeaths': 1,
#    'TotalDeaths': 41,
#    'NewRecovered': 30,
#    'TotalRecovered': 460,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 16,
#    'TotalConfirmed': 3711,
#    'NewDeaths': 0,
#    'TotalDeaths': 85,
#    'NewRecovered': 81,
#    'TotalRecovered': 3088,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Macao, SAR China',
#    'CountryCode': 'MO',
#    'Slug': 'macao-sar-china',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 41,
#    'TotalConfirmed': 1367,
#    'NewDeaths': 2,
#    'TotalDeaths': 59,
#    'NewRecovered': 37,
#    'TotalRecovered': 374,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 123,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 1,
#    'TotalRecovered': 62,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 51,
#    'TotalConfirmed': 5742,
#    'NewDeaths': 2,
#    'TotalDeaths': 98,
#    'NewRecovered': 99,
#    'TotalRecovered': 3762,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 177,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 1,
#    'TotalRecovered': 17,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 45,
#    'TotalConfirmed': 370,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 4,
#    'TotalRecovered': 91,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 448,
#    'NewDeaths': 1,
#    'TotalDeaths': 4,
#    'NewRecovered': 26,
#    'TotalRecovered': 249,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Martinique',
#    'CountryCode': 'MQ',
#    'Slug': 'martinique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 331,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 10,
#    'TotalRecovered': 295,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Mayotte',
#    'CountryCode': 'YT',
#    'Slug': 'mayotte',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 2209,
#    'TotalConfirmed': 13842,
#    'NewDeaths': 236,
#    'TotalDeaths': 1305,
#    'NewRecovered': 4522,
#    'TotalRecovered': 7149,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 194,
#    'TotalConfirmed': 3304,
#    'NewDeaths': 10,
#    'TotalDeaths': 94,
#    'NewRecovered': 70,
#    'TotalRecovered': 825,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 94,
#    'NewDeaths': 0,
#    'TotalDeaths': 4,
#    'NewRecovered': 1,
#    'TotalRecovered': 42,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 37,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 9,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 320,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 30,
#    'TotalRecovered': 153,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Montserrat',
#    'CountryCode': 'MS',
#    'Slug': 'montserrat',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 139,
#    'TotalConfirmed': 3897,
#    'NewDeaths': 1,
#    'TotalDeaths': 159,
#    'NewRecovered': 51,
#    'TotalRecovered': 537,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 70,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 12,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 146,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 1,
#    'TotalRecovered': 10,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Nauru',
#    'CountryCode': 'NR',
#    'Slug': 'nauru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 49,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 1,
#    'TotalRecovered': 12,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 655,
#    'TotalConfirmed': 37384,
#    'NewDeaths': 120,
#    'TotalDeaths': 4424,
#    'NewRecovered': 0,
#    'TotalRecovered': 102,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Netherlands Antilles',
#    'CountryCode': 'AN',
#    'Slug': 'netherlands-antilles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'New Caledonia',
#    'CountryCode': 'NC',
#    'Slug': 'new-caledonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 1470,
#    'NewDeaths': 0,
#    'TotalDeaths': 18,
#    'NewRecovered': 24,
#    'TotalRecovered': 1142,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 12,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 684,
#    'NewDeaths': 3,
#    'TotalDeaths': 27,
#    'NewRecovered': 36,
#    'TotalRecovered': 325,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 87,
#    'TotalConfirmed': 1182,
#    'NewDeaths': 3,
#    'TotalDeaths': 35,
#    'NewRecovered': 14,
#    'TotalRecovered': 222,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Niue',
#    'CountryCode': 'NU',
#    'Slug': 'niue',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Norfolk Island',
#    'CountryCode': 'NF',
#    'Slug': 'norfolk-island',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Northern Mariana Islands',
#    'CountryCode': 'MP',
#    'Slug': 'northern-mariana-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 36,
#    'TotalConfirmed': 7499,
#    'NewDeaths': 2,
#    'TotalDeaths': 201,
#    'NewRecovered': 0,
#    'TotalRecovered': 32,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 115,
#    'TotalConfirmed': 1905,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 4,
#    'TotalRecovered': 329,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 783,
#    'TotalConfirmed': 12723,
#    'NewDeaths': 16,
#    'TotalDeaths': 269,
#    'NewRecovered': 111,
#    'TotalRecovered': 2866,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 200,
#    'TotalConfirmed': 5538,
#    'NewDeaths': 5,
#    'TotalDeaths': 159,
#    'NewRecovered': 19,
#    'TotalRecovered': 338,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 228,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 7,
#    'TotalRecovered': 85,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 3683,
#    'TotalConfirmed': 25331,
#    'NewDeaths': 66,
#    'TotalDeaths': 700,
#    'NewRecovered': 301,
#    'TotalRecovered': 7797,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 102,
#    'TotalConfirmed': 7294,
#    'NewDeaths': 17,
#    'TotalDeaths': 494,
#    'NewRecovered': 30,
#    'TotalRecovered': 792,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Pitcairn',
#    'CountryCode': 'PN',
#    'Slug': 'pitcairn',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 381,
#    'TotalConfirmed': 11273,
#    'NewDeaths': 30,
#    'TotalDeaths': 524,
#    'NewRecovered': 182,
#    'TotalRecovered': 2126,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 595,
#    'TotalConfirmed': 23392,
#    'NewDeaths': 26,
#    'TotalDeaths': 880,
#    'NewRecovered': 49,
#    'TotalRecovered': 1277,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Puerto Rico',
#    'CountryCode': 'PR',
#    'Slug': 'puerto-rico',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 833,
#    'TotalConfirmed': 9358,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 120,
#    'TotalRecovered': 929,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 510,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 93,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 218,
#    'TotalConfirmed': 10635,
#    'NewDeaths': 34,
#    'TotalDeaths': 601,
#    'NewRecovered': 73,
#    'TotalRecovered': 2890,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 5966,
#    'TotalConfirmed': 74588,
#    'NewDeaths': 66,
#    'TotalDeaths': 681,
#    'NewRecovered': 682,
#    'TotalRecovered': 6250,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 183,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 1,
#    'TotalRecovered': 88,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Réunion',
#    'CountryCode': 'RE',
#    'Slug': 'réunion',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Saint Helena',
#    'CountryCode': 'SH',
#    'Slug': 'saint-helena',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 15,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Saint Pierre and Miquelon',
#    'CountryCode': 'PM',
#    'Slug': 'saint-pierre-and-miquelon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Saint-Barthélemy',
#    'CountryCode': 'BL',
#    'Slug': 'saint-barthélemy',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Saint-Martin (French part)',
#    'CountryCode': 'MF',
#    'Slug': 'saint-martin-french-part',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 513,
#    'NewDeaths': 0,
#    'TotalDeaths': 40,
#    'NewRecovered': 0,
#    'TotalRecovered': 64,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 1197,
#    'TotalConfirmed': 16299,
#    'NewDeaths': 9,
#    'TotalDeaths': 136,
#    'NewRecovered': 166,
#    'TotalRecovered': 2215,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 69,
#    'TotalConfirmed': 614,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 14,
#    'TotalRecovered': 276,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6630,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 870,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 82,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 10,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 618,
#    'TotalConfirmed': 12693,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 46,
#    'TotalRecovered': 1002,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 1373,
#    'NewDeaths': 0,
#    'TotalDeaths': 17,
#    'NewRecovered': 31,
#    'TotalRecovered': 386,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 15,
#    'TotalConfirmed': 1388,
#    'NewDeaths': 1,
#    'TotalDeaths': 81,
#    'NewRecovered': 8,
#    'TotalRecovered': 219,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 62,
#    'TotalConfirmed': 390,
#    'NewDeaths': 2,
#    'TotalDeaths': 18,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 141,
#    'TotalConfirmed': 4361,
#    'NewDeaths': 7,
#    'TotalDeaths': 86,
#    'NewRecovered': 0,
#    'TotalRecovered': 1473,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'South Georgia and the South Sandwich Islands',
#    'CountryCode': 'GS',
#    'Slug': 'south-georgia-and-the-south-sandwich-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 3995,
#    'TotalConfirmed': 223759,
#    'NewDeaths': 378,
#    'TotalDeaths': 22902,
#    'NewRecovered': 3353,
#    'TotalRecovered': 95708,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 40,
#    'TotalConfirmed': 460,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 9,
#    'TotalRecovered': 118,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 39,
#    'TotalConfirmed': 213,
#    'NewDeaths': 1,
#    'TotalDeaths': 17,
#    'NewRecovered': 5,
#    'TotalRecovered': 19,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Svalbard and Jan Mayen Islands',
#    'CountryCode': 'SJ',
#    'Slug': 'svalbard-and-jan-mayen-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 20,
#    'TotalConfirmed': 56,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 10,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 610,
#    'TotalConfirmed': 18177,
#    'NewDeaths': 40,
#    'TotalDeaths': 2192,
#    'NewRecovered': 0,
#    'TotalRecovered': 1005,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 217,
#    'TotalConfirmed': 28894,
#    'NewDeaths': 10,
#    'TotalDeaths': 1599,
#    'NewRecovered': 300,
#    'TotalRecovered': 21300,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 42,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 5,
#    'TotalRecovered': 11,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 429,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 11,
#    'TotalRecovered': 275,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 299,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 48,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2907,
#    'NewDeaths': 0,
#    'TotalDeaths': 51,
#    'NewRecovered': 0,
#    'TotalRecovered': 2547,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 96,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 3,
#    'TotalRecovered': 62,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Tokelau',
#    'CountryCode': 'TK',
#    'Slug': 'tokelau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Tonga',
#    'CountryCode': 'TO',
#    'Slug': 'tonga',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 115,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 5,
#    'TotalRecovered': 53,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 939,
#    'NewDeaths': 0,
#    'TotalDeaths': 38,
#    'NewRecovered': 13,
#    'TotalRecovered': 207,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 2861,
#    'TotalConfirmed': 107773,
#    'NewDeaths': 106,
#    'TotalDeaths': 2706,
#    'NewRecovered': 3845,
#    'TotalRecovered': 25582,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Turkmenistan',
#    'CountryCode': 'TM',
#    'Slug': 'turkmenistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Turks and Caicos Islands',
#    'CountryCode': 'TC',
#    'Slug': 'turks-and-caicos-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Tuvalu',
#    'CountryCode': 'TV',
#    'Slug': 'tuvalu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'US Minor Outlying Islands',
#    'CountryCode': 'UM',
#    'Slug': 'us-minor-outlying-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 75,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 46,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8125,
#    'NewDeaths': 0,
#    'TotalDeaths': 201,
#    'NewRecovered': 0,
#    'TotalRecovered': 782,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 532,
#    'TotalConfirmed': 9813,
#    'NewDeaths': 7,
#    'TotalDeaths': 71,
#    'NewRecovered': 127,
#    'TotalRecovered': 1887,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 4929,
#    'TotalConfirmed': 149569,
#    'NewDeaths': 814,
#    'TotalDeaths': 20381,
#    'NewRecovered': 50,
#    'TotalRecovered': 774,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 32737,
#    'TotalConfirmed': 937054,
#    'NewDeaths': 1803,
#    'TotalDeaths': 53724,
#    'NewRecovered': 1293,
#    'TotalRecovered': 100372,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 33,
#    'TotalConfirmed': 596,
#    'NewDeaths': 2,
#    'TotalDeaths': 14,
#    'NewRecovered': 1,
#    'TotalRecovered': 370,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 58,
#    'TotalConfirmed': 1862,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 86,
#    'TotalRecovered': 707,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 323,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 132,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 270,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 5,
#    'TotalRecovered': 225,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Virgin Islands, US',
#    'CountryCode': 'VI',
#    'Slug': 'virgin-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Wallis and Futuna Islands',
#    'CountryCode': 'WF',
#    'Slug': 'wallis-and-futuna-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Western Sahara',
#    'CountryCode': 'EH',
#    'Slug': 'western-sahara',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 84,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 37,
#    'Date': '2020-04-26T21:06:28Z'},
#   {'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 31,
#    'NewDeaths': 0,
#    'TotalDeaths': 4,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-26T21:06:28Z'}],
#  'Date': '2020-04-26T21:06:28Z'}

# %%
print(rawdata.keys())
# Out:
# dict_keys(['Global', 'Countries', 'Date'])

# %% [markdown]
# Creating a function to get COVID information for a single country - could use both country name ('Brazil') or country code ('BR'):

# %%
def get_country_info(country_name):
    for record in rawdata['Countries']:
        if record['Country'] == country_name.capitalize() or record['CountryCode'] == country_name.upper():
            return(record)

# %%
get_country_info('it') # Testing our function
# Out:
# {'Country': 'Italy',
#  'CountryCode': 'IT',
#  'Slug': 'italy',
#  'NewConfirmed': 2357,
#  'TotalConfirmed': 195351,
#  'NewDeaths': 415,
#  'TotalDeaths': 26384,
#  'NewRecovered': 2622,
#  'TotalRecovered': 63120,
#  'Date': '2020-04-26T21:06:28Z'}

# %% [markdown]
# Get only **total** and **new** cases confirmed, recovered and deaths for a given country:

# %%
data = get_country_info('Brazil')
print("Country: {}\nNew Confirmed: {}\nTotal Confirmed: {}\n\
New Recovered: {}\nTotal Recovered: {}\n\
New Deaths: {}\nTotal Deaths: {}".format(
    data['Country'],
    data['NewConfirmed'],
    data['TotalConfirmed'],
    data['NewRecovered'],
    data['TotalRecovered'],
    data['NewDeaths'],
    data['TotalDeaths']))
# Out:
# Country: Brazil
# New Confirmed: 5281
# Total Confirmed: 59324
# New Recovered: 1505
# Total Recovered: 29160
# New Deaths: 353
# Total Deaths: 4057
